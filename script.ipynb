-- %% [markdown]
-- # [HotelManagementDB]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [HotelManagementDB]    Script Date: 3/21/2025 4:48:10 AM ******/
CREATE DATABASE [HotelManagementDB]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'HotelDB', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.SQLEXPRESS\MSSQL\DATA\HotelDB.mdf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB ),
( NAME = N'HotelManagementDB', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.SQLEXPRESS\MSSQL\DATA\HotelManagementDB.ndf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'HotelDB_log', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.SQLEXPRESS\MSSQL\DATA\HotelDB_log.ldf' , SIZE = 8192KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
 WITH CATALOG_COLLATION = DATABASE_DEFAULT, LEDGER = OFF
GO
ALTER DATABASE [HotelManagementDB] SET COMPATIBILITY_LEVEL = 160
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [HotelManagementDB].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [HotelManagementDB] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [HotelManagementDB] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [HotelManagementDB] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [HotelManagementDB] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [HotelManagementDB] SET ARITHABORT OFF 
GO
ALTER DATABASE [HotelManagementDB] SET AUTO_CLOSE OFF 
GO
ALTER DATABASE [HotelManagementDB] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [HotelManagementDB] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [HotelManagementDB] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [HotelManagementDB] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [HotelManagementDB] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [HotelManagementDB] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [HotelManagementDB] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [HotelManagementDB] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [HotelManagementDB] SET  DISABLE_BROKER 
GO
ALTER DATABASE [HotelManagementDB] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [HotelManagementDB] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [HotelManagementDB] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [HotelManagementDB] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [HotelManagementDB] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [HotelManagementDB] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [HotelManagementDB] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [HotelManagementDB] SET RECOVERY SIMPLE 
GO
ALTER DATABASE [HotelManagementDB] SET  MULTI_USER 
GO
ALTER DATABASE [HotelManagementDB] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [HotelManagementDB] SET DB_CHAINING OFF 
GO
ALTER DATABASE [HotelManagementDB] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [HotelManagementDB] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [HotelManagementDB] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [HotelManagementDB] SET ACCELERATED_DATABASE_RECOVERY = OFF  
GO
ALTER DATABASE [HotelManagementDB] SET QUERY_STORE = ON
GO
ALTER DATABASE [HotelManagementDB] SET QUERY_STORE (OPERATION_MODE = READ_WRITE, CLEANUP_POLICY = (STALE_QUERY_THRESHOLD_DAYS = 30), DATA_FLUSH_INTERVAL_SECONDS = 900, INTERVAL_LENGTH_MINUTES = 60, MAX_STORAGE_SIZE_MB = 1000, QUERY_CAPTURE_MODE = AUTO, SIZE_BASED_CLEANUP_MODE = AUTO, MAX_PLANS_PER_QUERY = 200, WAIT_STATS_CAPTURE_MODE = ON)
GO

-- %% [markdown]
-- # [dbo].[Bookings]

-- %%
USE [HotelManagementDB]
GO

-- %%
/****** Object:  Table [dbo].[Bookings]    Script Date: 3/21/2025 4:48:10 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Bookings](
	[BookingId] [int] IDENTITY(1,1) NOT NULL,
	[GuestName] [nvarchar](100) NOT NULL,
	[Email] [nvarchar](100) NOT NULL,
	[PhoneNumber] [nvarchar](20) NULL,
	[RoomId] [int] NOT NULL,
	[CheckInDate] [datetime] NOT NULL,
	[CheckOutDate] [datetime] NOT NULL,
	[TotalPrice] [decimal](10, 2) NOT NULL,
	[Status] [nvarchar](20) NULL,
	[UserId] [nvarchar](450) NULL,
	[CheckedInAt] [datetime] NULL,
	[CheckedOutAt] [datetime] NULL,
	[BookingType] [nvarchar](50) NULL,
	[CreatedAt] [datetime] NULL,
	[PaymentStatus] [nvarchar](50) NULL,
	[UpdatedAt] [datetime] NULL,
	[PaymentMethod] [nvarchar](50) NULL,
	[TransactionId] [nvarchar](100) NULL,
PRIMARY KEY CLUSTERED 
(
	[BookingId] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[HousekeepingTasks]

-- %%
/****** Object:  Table [dbo].[HousekeepingTasks]    Script Date: 3/21/2025 4:48:10 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[HousekeepingTasks](
	[TaskId] [int] IDENTITY(1,1) NOT NULL,
	[RoomId] [int] NULL,
	[AssignedTo] [int] NULL,
	[Status] [nvarchar](50) NULL,
	[ScheduledDate] [date] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[TaskId] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Invoices]

-- %%
/****** Object:  Table [dbo].[Invoices]    Script Date: 3/21/2025 4:48:10 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Invoices](
	[InvoiceId] [int] IDENTITY(1,1) NOT NULL,
	[BookingId] [int] NULL,
	[TotalAmount] [decimal](10, 2) NOT NULL,
	[Status] [nvarchar](50) NULL,
	[GeneratedAt] [datetime] NULL,
PRIMARY KEY CLUSTERED 
(
	[InvoiceId] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[MaintenanceRequests]

-- %%
/****** Object:  Table [dbo].[MaintenanceRequests]    Script Date: 3/21/2025 4:48:10 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[MaintenanceRequests](
	[RequestId] [int] IDENTITY(1,1) NOT NULL,
	[RoomId] [int] NULL,
	[Description] [nvarchar](255) NOT NULL,
	[Status] [nvarchar](50) NULL,
	[ReportedAt] [datetime] NULL,
PRIMARY KEY CLUSTERED 
(
	[RequestId] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Payments]

-- %%
/****** Object:  Table [dbo].[Payments]    Script Date: 3/21/2025 4:48:10 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Payments](
	[PaymentId] [int] IDENTITY(1,1) NOT NULL,
	[BookingId] [int] NULL,
	[PaymentMethod] [nvarchar](50) NOT NULL,
	[PaymentStatus] [nvarchar](50) NULL,
	[Amount] [decimal](10, 2) NOT NULL,
	[TransactionId] [nvarchar](100) NULL,
	[ProcessedAt] [datetime] NULL,
PRIMARY KEY CLUSTERED 
(
	[PaymentId] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY],
UNIQUE NONCLUSTERED 
(
	[TransactionId] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Reports]

-- %%
/****** Object:  Table [dbo].[Reports]    Script Date: 3/21/2025 4:48:10 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Reports](
	[ReportId] [int] IDENTITY(1,1) NOT NULL,
	[ReportType] [nvarchar](50) NOT NULL,
	[GeneratedBy] [int] NULL,
	[GeneratedAt] [datetime] NULL,
PRIMARY KEY CLUSTERED 
(
	[ReportId] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Rooms]

-- %%
/****** Object:  Table [dbo].[Rooms]    Script Date: 3/21/2025 4:48:10 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Rooms](
	[RoomId] [int] IDENTITY(1,1) NOT NULL,
	[RoomNumber] [nvarchar](20) NOT NULL,
	[Category] [nvarchar](50) NOT NULL,
	[Status] [nvarchar](20) NOT NULL,
	[PricePerNight] [decimal](10, 2) NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[RoomId] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY],
UNIQUE NONCLUSTERED 
(
	[RoomNumber] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Users]

-- %%
/****** Object:  Table [dbo].[Users]    Script Date: 3/21/2025 4:48:10 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Users](
	[UserId] [int] IDENTITY(1,1) NOT NULL,
	[FirstName] [nvarchar](50) NOT NULL,
	[LastName] [nvarchar](50) NOT NULL,
	[Email] [nvarchar](100) NOT NULL,
	[PasswordHash] [nvarchar](255) NOT NULL,
	[CreatedAt] [datetime] NOT NULL,
	[Role] [nvarchar](20) NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[UserId] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY],
UNIQUE NONCLUSTERED 
(
	[Email] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [DF__Bookings__Create__6383C8BA]

-- %%
ALTER TABLE [dbo].[Bookings] ADD  DEFAULT (getdate()) FOR [CreatedAt]
GO

-- %% [markdown]
-- # [DF__Housekeep__Statu__6E01572D]

-- %%
ALTER TABLE [dbo].[HousekeepingTasks] ADD  DEFAULT ('Pending') FOR [Status]
GO

-- %% [markdown]
-- # [DF__Invoices__Status__76969D2E]

-- %%
ALTER TABLE [dbo].[Invoices] ADD  DEFAULT ('Unpaid') FOR [Status]
GO

-- %% [markdown]
-- # [DF__Invoices__Genera__778AC167]

-- %%
ALTER TABLE [dbo].[Invoices] ADD  DEFAULT (getdate()) FOR [GeneratedAt]
GO

-- %% [markdown]
-- # [DF__Maintenan__Statu__71D1E811]

-- %%
ALTER TABLE [dbo].[MaintenanceRequests] ADD  DEFAULT ('Pending') FOR [Status]
GO

-- %% [markdown]
-- # [DF__Maintenan__Repor__72C60C4A]

-- %%
ALTER TABLE [dbo].[MaintenanceRequests] ADD  DEFAULT (getdate()) FOR [ReportedAt]
GO

-- %% [markdown]
-- # [DF__Payments__Paymen__68487DD7]

-- %%
ALTER TABLE [dbo].[Payments] ADD  DEFAULT ('Pending') FOR [PaymentStatus]
GO

-- %% [markdown]
-- # [DF__Payments__Proces__693CA210]

-- %%
ALTER TABLE [dbo].[Payments] ADD  DEFAULT (getdate()) FOR [ProcessedAt]
GO

-- %% [markdown]
-- # [DF__Reports__Generat__7B5B524B]

-- %%
ALTER TABLE [dbo].[Reports] ADD  DEFAULT (getdate()) FOR [GeneratedAt]
GO

-- %% [markdown]
-- # [DF__Users__CreatedAt__38996AB5]

-- %%
ALTER TABLE [dbo].[Users] ADD  DEFAULT (getdate()) FOR [CreatedAt]
GO

-- %% [markdown]
-- # [DF__Users__Role__398D8EEE]

-- %%
ALTER TABLE [dbo].[Users] ADD  DEFAULT ('Guest') FOR [Role]
GO

-- %% [markdown]
-- # [FK__Bookings__RoomId__3F466844]

-- %%
ALTER TABLE [dbo].[Bookings]  WITH CHECK ADD FOREIGN KEY([RoomId])
REFERENCES [dbo].[Rooms] ([RoomId])
ON DELETE CASCADE
GO

-- %% [markdown]
-- # [FK__Housekeep__Assig__6D0D32F4]

-- %%
ALTER TABLE [dbo].[HousekeepingTasks]  WITH CHECK ADD FOREIGN KEY([AssignedTo])
REFERENCES [dbo].[Users] ([UserId])
GO

-- %% [markdown]
-- # [FK__Housekeep__RoomI__6C190EBB]

-- %%
ALTER TABLE [dbo].[HousekeepingTasks]  WITH CHECK ADD FOREIGN KEY([RoomId])
REFERENCES [dbo].[Rooms] ([RoomId])
GO

-- %% [markdown]
-- # [FK__Invoices__Bookin__75A278F5]

-- %%
ALTER TABLE [dbo].[Invoices]  WITH CHECK ADD FOREIGN KEY([BookingId])
REFERENCES [dbo].[Bookings] ([BookingId])
GO

-- %% [markdown]
-- # [FK__Maintenan__RoomI__70DDC3D8]

-- %%
ALTER TABLE [dbo].[MaintenanceRequests]  WITH CHECK ADD FOREIGN KEY([RoomId])
REFERENCES [dbo].[Rooms] ([RoomId])
GO

-- %% [markdown]
-- # [FK__Payments__Bookin__6754599E]

-- %%
ALTER TABLE [dbo].[Payments]  WITH CHECK ADD FOREIGN KEY([BookingId])
REFERENCES [dbo].[Bookings] ([BookingId])
GO

-- %% [markdown]
-- # [FK__Reports__Generat__7A672E12]

-- %%
ALTER TABLE [dbo].[Reports]  WITH CHECK ADD FOREIGN KEY([GeneratedBy])
REFERENCES [dbo].[Users] ([UserId])
GO

-- %% [markdown]
-- # [CHK_BookingType]

-- %%
ALTER TABLE [dbo].[Bookings]  WITH CHECK ADD  CONSTRAINT [CHK_BookingType] CHECK  (([BookingType]='Walk-In' OR [BookingType]='Reservation' OR [BookingType]='Booking'))
GO
ALTER TABLE [dbo].[Bookings] CHECK CONSTRAINT [CHK_BookingType]
GO

-- %% [markdown]
-- # [CHK_CheckIn_CheckOut]

-- %%
ALTER TABLE [dbo].[Bookings]  WITH CHECK ADD  CONSTRAINT [CHK_CheckIn_CheckOut] CHECK  (([CheckOutDate]>[CheckInDate]))
GO
ALTER TABLE [dbo].[Bookings] CHECK CONSTRAINT [CHK_CheckIn_CheckOut]
GO

-- %% [markdown]
-- # [CHK_TotalPrice]

-- %%
ALTER TABLE [dbo].[Bookings]  WITH CHECK ADD  CONSTRAINT [CHK_TotalPrice] CHECK  (([TotalPrice]>=(0)))
GO
ALTER TABLE [dbo].[Bookings] CHECK CONSTRAINT [CHK_TotalPrice]
GO

-- %% [markdown]
-- # [HotelManagementDB]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [HotelManagementDB] SET  READ_WRITE 
GO
